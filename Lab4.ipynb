# %%
# %pip install qiskit-aer
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
from warnings import filterwarnings
filterwarnings("ignore")
# Out:
# Requirement already satisfied: qiskit-aer in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit-aer) (2.1.2)
# Requirement already satisfied: numpy>=1.16.3 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit-aer) (2.3.3)
# Requirement already satisfied: scipy>=1.0 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit-aer) (1.16.2)
# Requirement already satisfied: psutil>=5 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit-aer) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /Users/abhijith/miniforge3/envs/qiskit_env/lib/python3.11/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
circuit = QuantumCircuit(1)

circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)

display(circuit.draw(output='mpl'))

# %%
X = QuantumRegister(1, "X")
circuit = QuantumCircuit(X)

circuit.h(X)
circuit.s(X)
circuit.h(X)
circuit.t(X)

display(circuit.draw(output='mpl'))

# %%
X = QuantumRegister(1, "X")
Y = QuantumRegister(1, "Y")
A = ClassicalRegister(1, "A")
B = ClassicalRegister(1, "B")

circuit = QuantumCircuit(Y, X, B, A)
circuit.h(Y)
circuit.cx(Y, X)
circuit.measure(Y, B)
circuit.measure(X, A)

display(circuit.draw(output='mpl'))

# %%
from qiskit import transpile

# use AerSimulator to run the circuit and get counts
sim = AerSimulator()
compiled = transpile(circuit, sim)
job = sim.run(compiled)
results = job.result()
counts = results.get_counts()
display(plot_histogram(counts))
